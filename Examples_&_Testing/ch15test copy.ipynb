# %%
# %matplotlib inline
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %%
iris.data.shape
iris.target.shape
iris.target_names
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
import pandas as pd

pd.set_option('display.max_columns', 5)  # Corrected option key
pd.set_option('display.width', None)

from sklearn import datasets

iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

print(iris_df.head())
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = [iris.target_names[i] for i in iris.target]
iris_df.head()
pd.set_option('precision', 2)
iris_df.describe()
iris_df['species'].describe()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[12], line 15
#      13 iris_df['species'] = [iris.target_names[i] for i in iris.target]
#      14 iris_df.head()
# ---> 15 pd.set_option('precision', 2)
#      16 iris_df.describe()
#      17 iris_df['species'].describe()
#
# File c:\Projects\datafun-07-ml\.venv\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
# ...

# %%
import seaborn as sns
sns.set(font_scale=1.1)
sns.set_style('whitegrid')
grid = sns.pairplot(data=iris_df, vars=iris_df.columns[0:4],
     hue='species')

# %%
import matplotlib.pyplot as plt
iris_centers = pca.transform(kmean.cluster_centers)
dots = plt.scatter(iris_centers[:,0], iris_centers[:,1], s=100, c='k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 iris_centers = pca.transform(kmean.cluster_centers)
#       3 dots = plt.scatter(iris_centers[:,0], iris_centers[:,1], s=100, c='k')
#
# NameError: name 'pca' is not defined
